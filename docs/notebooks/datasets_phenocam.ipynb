# %% [markdown]
# ## Observations from [Phenocam](hhttps://phenocam.nau.edu/webcam/)
#
# ### Data from harvard site

# %%
from springtime.datasets.phenocam import PhenocamrSite, list_sites

# %% [markdown]
# Retrieve meta data on "harvard" site.

# %%
sites = list_sites()
sites[sites.site == "harvard"]
# Out:
#         site      lat      lon  elev  \
# 207  harvard  42.5378 -72.1715   340
#
#                                               contact1  \
# 207  Andrew Richardson <andrew DOT richardson AT na...
#
#                                               contact2  date_start  \
# 207  Bill Munger <jwmunger AT seas DOT harvard DOT ...  2008-04-04
#
#        date_end  nimage  tzoffset  ...  MAP_worldclim  \
# 207  2023-04-12  180576        -5  ...         1139.0
#
#                               dominant_species primary_veg_type  \
# 207  Quercus rubra, Acer rubrum, Pinus strobus               DB
#
#     secondary_veg_type koeppen_geiger ecoregion wwf_biome landcover_igbp  \
# 207                 EN            Dfb         5         4              5
#
#                                  site_acknowledgements  \
# 207  The Harvard EMS site is supported is an AmeriF...
#
#                        geometry
# 207  POINT (-72.17150 42.53780)
#
# [1 rows x 36 columns]

# %%
# Use $ in site name to get an exact match
dataset = PhenocamrSite(site='harvard$', years=(2010,2015))
dataset
# Out:
# PhenocamrSite(dataset='phenocam', years=YearRange(start=2010, end=2015), site='harvard$', veg_type=None, frequency='3', rois=None)

# %%
# Create a data instance
dataset.download()
# Out:
# Downloading phenocam rois to /tmp/data/phenocam/roi_data.csv
# R[write to console]: Downloading: harvard_DB_0001_3day.csv
#
# R[write to console]: -- Flagging outliers!
#
# R[write to console]: -- Smoothing time series!
#
# R[write to console]: Downloading: harvard_DB_1000_3day.csv
#
# R[write to console]: -- Flagging outliers!
#
# R[write to console]: -- Smoothing time series!

# %%
# Load downloded dataset as a dataframe
df = dataset.load()
df.head()
# Out:
#         site roi_id_number veg_type        date  year  doy  image_count  \
# 727  harvard          0001       DB  2010-01-01  2010    1          NaN
# 728  harvard          0001       DB  2010-01-02  2010    2         26.0
# 729  harvard          0001       DB  2010-01-03  2010    3          NaN
# 730  harvard          0001       DB  2010-01-04  2010    4          NaN
# 731  harvard          0001       DB  2010-01-05  2010    5         39.0
#
#                    midday_filename  midday_r  midday_g  ...  smooth_rcc_90  \
# 727                            NaN       NaN       NaN  ...        0.31122
# 728  harvard_2010_01_02_120137.jpg  52.19172  71.35788  ...        0.31119
# 729                            NaN       NaN       NaN  ...        0.31127
# 730                            NaN       NaN       NaN  ...        0.31138
# 731  harvard_2010_01_05_120139.jpg  54.79733  68.07477  ...        0.31144
#
#      smooth_ci_gcc_mean  smooth_ci_gcc_50  smooth_ci_gcc_75  smooth_ci_gcc_90  \
# 727             0.00307           0.00305           0.00320           0.00372
# 728             0.00304           0.00302           0.00316           0.00368
# 729             0.00304           0.00302           0.00317           0.00368
# 730             0.00308           0.00306           0.00320           0.00372
# 731             0.00310           0.00309           0.00323           0.00376
#
#      smooth_ci_rcc_mean  smooth_ci_rcc_50  smooth_ci_rcc_75  smooth_ci_rcc_90  \
# 727             0.00735           0.00812           0.00710           0.00670
# 728             0.00728           0.00804           0.00703           0.00664
# 729             0.00728           0.00804           0.00704           0.00664
# 730             0.00737           0.00814           0.00712           0.00672
# 731             0.00743           0.00821           0.00718           0.00677
#
#      int_flag
# 727       NaN
# 728       NaN
# 729       NaN
# 730       NaN
# 731       NaN
#
# [5 rows x 52 columns]
