# %%
from rich import print
import logging

logging.basicConfig(level=logging.INFO)

# %% [markdown]
# # National Phenology Network (NPN)
#
# This page demonstrates how to retrieve data from the [National Phenology Network
# (NPN)](https://www.usanpn.org/usa-national-phenology-network) using springtime.
#
# **Species:** Syringa vulgaris
# <br>
# **Phenophase (fb):** 483 (?)

# %%
from springtime.datasets.insitu.npn.rnpn import RNPN, npn_species, npn_phenophases
# Out:
# INFO:rpy2.situation:cffi mode is CFFI_MODE.ANY
# INFO:rpy2.situation:R home found: /home/peter/mambaforge/envs/springtime/lib/R
# INFO:rpy2.situation:R library path:
# INFO:rpy2.situation:LD_LIBRARY_PATH:
# INFO:rpy2.rinterface_lib.embedded:Default options to initialize R: rpy2, --quiet, --no-save
# INFO:rpy2.rinterface_lib.embedded:R is already initialized. No need to initialize.

# %% [markdown]
# ## Listing species and phenophases
#
# Before we can download any data, we need to know which species and phenophases are available. To this end, we can use the `npn_species` and `npn_phenophases` functions.

# %%
species = npn_species()
species
# Out:
# ERROR:springtime.utils:b"Service is unavailable. Try again later!\nError in eval(substitute(select), nl, parent.frame()) : \n  object 'species_type' not found\nCalls: subset -> subset.data.frame -> eval -> eval\nExecution halted\n"
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 species = npn_species()
#
# File ~/phenology/springtime/src/springtime/datasets/insitu/npn/rnpn.py:216, in npn_species()
#     208     cache_dir.mkdir(parents=True, exist_ok=True)
#     209     script = f"""\
#     210         library(rnpn)
#     211         # species_type column has nested df, which can not be converted, so drop it
#    (...)
#     214                     eol="\n", row.names=FALSE, col.names=TRUE)
#     215     """
# --> 216     run_r_script(script)
#     217 return pd.read_csv(species_file)
#
# File ~/phenology/springtime/src/springtime/utils.py:226, in run_r_script(script, timeout, max_tries)
#     220 result = retry(timeout=timeout, max_tries=max_tries)(subprocess.run)(
#     221     ["R", "--vanilla", "--no-echo"],
#     222     input=script.encode(),
#     223     stderr=subprocess.PIPE,
#     224 )
#     225 try:
# --> 226     result.check_returncode()
#     227 except subprocess.CalledProcessError:
#     228     logger.error(result.stderr)
#
# File ~/mambaforge/envs/springtime/lib/python3.10/subprocess.py:456, in CompletedProcess.check_returncode(self)
#     454 """Raise CalledProcessError if the exit code is non-zero."""
#     455 if self.returncode:
# --> 456     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     457                              self.stderr)
#
# CalledProcessError: Command '['R', '--vanilla', '--no-echo']' returned non-zero exit status 1.

# %%
phenophases = npn_phenophases()
phenophases

# %%
# Out:
#      phenophase_id       phenophase_name phenophase_category   color  \
# 0               56           First leaf               Leaves     NaN
# 1               57  75% leaf elongation               Leaves     NaN
# 2               58         First flower              Flowers     NaN
# 3               59           Last flower             Flowers     NaN
# 4               60     First fruit ripe               Fruits     NaN
# ..             ...                   ...                 ...     ...
# 194            545   Post-dormant nymphs         Development  Brown3
# 195            546              Crawlers         Development  Brown3
# 196            547            Egg laying        Reproduction  Brown2
# 197            548           Egg laying         Reproduction  Brown2
# 198            549               Mating         Reproduction  Brown2
#
#      pheno_class_id
# 0                 1
# 1                 2
# 2                 7
# 3                 9
# 4                12
# ..              ...
# 194             113
# 195             112
# 196             136
# 197             136
# 198              82
#
# [199 rows x 5 columns]

# %%
species[species.species_id == 36]
# Out:
#      species_id   common_name    genus  genus_id genus_common_name   species  \
# 421          36  common lilac  Syringa      1035  Lilacs (Syringa)  vulgaris
#
#      kingdom  itis_taxonomic_sn      functional_type  class_id  \
# 421  Plantae            32996.0  Deciduous broadleaf        15
#
#     class_common_name     class_name  order_id  \
# 421  Flowering Plants  Magnoliopsida        83
#
#                      order_common_name order_name  family_id family_name  \
# 421  Mint, Olive and Plantain Families   Lamiales        305    Oleaceae
#
#     family_common_name
# 421       Olive Family

# %%
phenophases[phenophases.phenophase_id == 483]
# Out:
#      phenophase_id phenophase_name phenophase_category   color  pheno_class_id
# 138            483          Leaves              Leaves  Green1               3

# %%
# Create a data instance
dataset = RNPN(
    species_ids={"name": "Syringa", "items": [36]},
    phenophase_ids={"name": "leaves", "items": [483]},
    years=[2010, 2011],
)
dataset
# Out:
# RNPN(dataset='RNPN', years=YearRange(start=2010, end=2011), species_ids=NamedIdentifiers(name='Syringa', items=[36]), phenophase_ids=NamedIdentifiers(name='leaves', items=[483]), area=None, use_first=True, aggregation_operator='min')

# %%
# Download data
dataset.download()
# Out:
# /tmp/data/rnpn/rnpn_npn_data_y_2010_Syringa_leaves.csv already exists, skipping
# /tmp/data/rnpn/rnpn_npn_data_y_2011_Syringa_leaves.csv already exists, skipping

# %%
# Load downloded data as a dataframe
df = dataset.load()
df
# Out:
#                       geometry   datetime  leaves_doy
# 0   POINT (-91.37602 38.38862) 2010-03-01          60
# 1   POINT (-79.97169 39.53892) 2010-05-05         125
# 2   POINT (-85.60993 39.79147) 2010-04-12         102
# 3   POINT (-76.62881 40.94780) 2010-04-05          95
# 4   POINT (-91.69318 41.29201) 2010-04-12         102
# 5   POINT (-91.48378 41.88856) 2010-04-04          94
# 6   POINT (-74.29987 42.10105) 2010-04-09          99
# 7   POINT (-77.43737 42.89832) 2010-04-08          98
# 8   POINT (-83.05326 35.59232) 2011-04-13         103
# 9   POINT (-80.53153 35.59463) 2011-03-14          73
# 10  POINT (-84.17097 35.65687) 2011-03-10          69
# 11  POINT (-86.96690 36.39927) 2011-02-25          56
# 12  POINT (-91.78845 36.65863) 2011-03-21          80
# 13  POINT (-90.15485 38.71774) 2011-03-19          78
# 14  POINT (-83.82374 38.82653) 2011-03-23          82
# 15  POINT (-84.52015 38.88288) 2011-03-21          80
# 16  POINT (-85.24599 38.99372) 2011-04-11         101
# 17  POINT (-81.54738 39.24728) 2011-03-18          77
# 18  POINT (-77.48402 39.72047) 2011-04-11         101
# 19  POINT (-79.89363 40.66472) 2011-04-04          94
# 20  POINT (-73.11993 40.85247) 2011-03-22          81
# 21  POINT (-77.44374 40.98488) 2011-04-14         104
# 22  POINT (-80.29738 41.04120) 2011-04-13         103
# 23  POINT (-74.59502 41.12333) 2011-04-30         120
# 24  POINT (-80.81221 41.13425) 2011-05-01         121
# 25  POINT (-85.12750 41.21440) 2011-04-15         105
# 26  POINT (-72.63346 41.91122) 2011-04-27         117
# 27  POINT (-80.33588 42.01947) 2011-04-29         119
# 28  POINT (-79.26913 42.09705) 2011-04-23         113
# 29  POINT (-80.01417 42.13030) 2011-04-20         110
# 30  POINT (-73.65140 42.33499) 2011-04-18         108
# 31  POINT (-83.21512 42.49105) 2011-04-23         113
# 32  POINT (-88.16408 42.98386) 2011-05-12         132

# %% [markdown]
# ## TODO
#
# - Wait for server to be back up
# - Datetime --> year only
# - More description in notebook
# - Add tests
# - Add to docs
